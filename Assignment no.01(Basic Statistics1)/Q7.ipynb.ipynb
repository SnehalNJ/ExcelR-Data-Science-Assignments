# %%
from scipy import stats

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('Q7.csv')

# %%
df.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   Points      32 non-null     float64
#  2   Score       32 non-null     float64
#  3   Weigh       32 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.1+ KB

# %%
df.rename(columns={'Unnamed: 0':'cars'}, inplace=True)

# %% [markdown]
# # mean

# %%
df_mean=df.groupby('cars').mean(numeric_only=True)

# %%
df_mean.mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %% [markdown]
# #### The mean value for points:3.5
# ####                                  scores:3.21
# ####                                  weigh:17.84

# %% [markdown]
# # median

# %%
df_mean.median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %% [markdown]
# #### The median value for points:3.6
# ####                                  scores:3.3
# ####                                  weigh:17.7

# %% [markdown]
# # mode

# %%
df_mean.mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %% [markdown]
# # Variance

# %%
df_mean.var()
# Out:
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %% [markdown]
# # standard deviation

# %%
df_mean.std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %% [markdown]
# # range

# %%
dmin=df_mean.min()

# %%
dmin
# Out:
# Points     2.760
# Score      1.513
# Weigh     14.500
# dtype: float64

# %%
dmax=df_mean.max()
dmax
# Out:
# Points     4.930
# Score      5.424
# Weigh     22.900
# dtype: float64

# %%
drange=dmax-dmin

# %%
drange
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64

# %%
plt.figure(figsize=(9,3))
plt.plot(df_mean.Points,color='red')
plt.title('Points')
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.plot(df_mean.Score,color='green')
plt.title('Score')
plt.show()

# %%
plt.figure(figsize=(9,3))
plt.plot(df_mean.Weigh,color='blue')
plt.title('Weigh')
plt.show()

# %%
plt.boxplot(df_mean.Points)
plt.title('Points')
plt.show()

# %%
plt.boxplot(df_mean.Score)
plt.title('Score')
plt.show()

# %%
plt.boxplot(df_mean.Weigh)
plt.title('Weigh')
plt.show()
